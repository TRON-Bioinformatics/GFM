# %%
# %%bash
# pytest test_gfm_run_all.py -q
# Out:
# ..                                                                       [100%]
# 2 passed in 1.16s

# %%
# %%bash
# pytest -q test_package_imports.py
# Out:
# ..                                                                       [100%]
# 2 passed in 0.62s
